# %%
#Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import signal
from scipy import stats
import seaborn as sns
sns.set()

# %% [markdown]
# 1. Load Data

# %%
#Import -> LEG_SENSOR
#Male 1
male1_leg_stand = pd.read_csv("raw_data\\male_1\\leg\\male1_rightleg_standing.csv")
male1_leg_walk = pd.read_csv('raw_data\\male_1\\leg\\male1_rightleg_walking.csv')
male1_leg_jog = pd.read_csv('raw_data\\male_1\\leg\\male1_rightleg_jogging.csv')
male1_leg_run = pd.read_csv('raw_data\\male_1\\leg\\male1_rightleg_running.csv')

#Male 2
male2_leg_stand = pd.read_csv('raw_data\\male_2\\leg\\male2_rightleg_standing.csv')
male2_leg_walk = pd.read_csv('raw_data\\male_2\\leg\\male2_rightleg_walking.csv')
male2_leg_jog = pd.read_csv('raw_data\\male_2\\leg\\male2_rightleg_jogging.csv')
male2_leg_run = pd.read_csv('raw_data\\male_2\\leg\\male2_rightleg_running.csv')

#Male 3
male3_leg_stand = pd.read_csv('raw_data\\male_3\\leg\\male3_rightleg_standing.csv')
male3_leg_walk = pd.read_csv('raw_data\\male_3\\leg\\male3_rightleg_walking.csv')
male3_leg_jog = pd.read_csv('raw_data\\male_3\\leg\\male3_rightleg_jogging.csv')
male3_leg_run = pd.read_csv('raw_data\\male_3\\leg\\male3_rightleg_running.csv')

#Female 1
female1_leg_stand = pd.read_csv('raw_data\\female_1\\leg\\female1_rightleg_standing.csv')
female1_leg_walk = pd.read_csv('raw_data\\female_1\\leg\\female1_rightleg_walking.csv')
female1_leg_jog = pd.read_csv('raw_data\\female_1\\leg\\female1_rightleg_jogging.csv')
female1_leg_run = pd.read_csv('raw_data\\female_1\leg\\female1_rightleg_running.csv')

#Female 2
female2_leg_stand = pd.read_csv("raw_data\\female_2\\leg\\female2_rightleg_standing.csv")
female2_leg_walk = pd.read_csv('raw_data\\female_2\\leg\\female2_rightleg_walking.csv')
female2_leg_jog = pd.read_csv('raw_data\\female_2\\leg\\female2_rightleg_jogging.csv')
female2_leg_run = pd.read_csv('raw_data\\female_2\\leg\\female2_rightleg_running.csv')

#Female 3
female3_leg_stand = pd.read_csv('raw_data\\female_3\\leg\\female3_rightleg_standing.csv')
female3_leg_walk = pd.read_csv('raw_data\\female_3\\leg\\female3_rightleg_walking.csv')
female3_leg_jog = pd.read_csv('raw_data\\female_3\\leg\\female3_rightleg_jogging.csv')
female3_leg_run = pd.read_csv('raw_data\\female_3\\leg\\female3_rightleg_running.csv')

# %%
#Import -> ARM_SENSOR
#Male 1
male1_arm_stand = pd.read_csv('raw_data\\male_1\\arm\\male1_rightarm_standing.csv')
male1_arm_walk = pd.read_csv('raw_data\\male_1\\arm\\male1_rightarm_walking.csv')
male1_arm_jog = pd.read_csv('raw_data\\male_1\\arm\\male1_rightarm_jogging.csv')
male1_arm_run = pd.read_csv('raw_data\\male_1\\arm\\male1_rightarm_running.csv')

#Male 2
male2_arm_stand = pd.read_csv('raw_data\\male_2\\arm\\male2_rightarm_standing.csv')
male2_arm_walk = pd.read_csv('raw_data\\male_2\\arm\\male2_rightarm_walking.csv')
male2_arm_jog = pd.read_csv('raw_data\\male_2\\arm\\male2_rightarm_jogging.csv')
male2_arm_run = pd.read_csv('raw_data\\male_2\\arm\\male2_rightarm_running.csv')

#Male 3
male3_arm_stand = pd.read_csv('raw_data\\male_3\\arm\\male3_rightarm_standing.csv')
male3_arm_walk = pd.read_csv('raw_data\\male_3\\arm\\male3_rightarm_walking.csv')
male3_arm_jog = pd.read_csv('raw_data\\male_3\\arm\\male3_rightarm_jogging.csv')
male3_arm_run = pd.read_csv('raw_data\\male_3\\arm\\male3_rightarm_running.csv')

#Female 1
female1_arm_stand = pd.read_csv('raw_data\\female_1\\arm\\female1_rightarm_standing.csv')
female1_arm_walk = pd.read_csv('raw_data\\female_1\\arm\\female1_rightarm_walking.csv')
female1_arm_jog = pd.read_csv('raw_data\\female_1\\arm\\female1_rightarm_jogging.csv')
female1_arm_run = pd.read_csv('raw_data\\female_1\\arm\\female1_rightarm_running.csv')

#Female 2
female2_arm_stand = pd.read_csv('raw_data\\female_2\\arm\\female2_rightarm_standing.csv')
female2_arm_walk = pd.read_csv('raw_data\\female_2\\arm\\female2_rightarm_walking.csv')
female2_arm_jog = pd.read_csv('raw_data\\female_2\\arm\\female2_rightarm_jogging.csv')
female2_arm_run = pd.read_csv('raw_data\\female_2\\arm\\female2_rightarm_running.csv')

#Female 3
female3_arm_stand = pd.read_csv('raw_data\\female_3\\arm\\female3_rightarm_standing.csv')
female3_arm_walk = pd.read_csv('raw_data\\female_3\\arm\\female3_rightarm_walking.csv')
female3_arm_jog = pd.read_csv('raw_data\\female_3\\arm\\female3_rightarm_jogging.csv')
female3_arm_run = pd.read_csv('raw_data\\female_3\\arm\\female3_rightarm_running.csv')

# %% [markdown]
# 02. Data Exploration

# %%
#Helper Function-> Visualise Activity Per User for 1 Sensor
def visualise_user_data(stand, walk, jog, run, user_info):
    plt.figure(figsize=(15,20))
    
    p1 = plt.subplot(4,1,1)
    p2 = plt.subplot(4,1,2)
    p3 = plt.subplot(4,1,3)
    p4 = plt.subplot(4,1,4)

    p1.plot(stand['ax (m/s^2)'], label='x acceleration')
    p1.plot(stand['ay (m/s^2)'], label='y acceleration')
    p1.plot(stand['az (m/s^2)'], label='z acceleration')
    p1.plot(stand['aT (m/s^2)'], label='total acceleration')

    p2.plot(walk['ax (m/s^2)'], label='x acceleration')
    p2.plot(walk['ay (m/s^2)'], label='y acceleration')
    p2.plot(walk['az (m/s^2)'], label='z acceleration')
    p2.plot(walk['aT (m/s^2)'], label='total acceleration')

    p3.plot(jog['ax (m/s^2)'], label='x acceleration')
    p3.plot(jog['ay (m/s^2)'], label='y acceleration')
    p3.plot(jog['az (m/s^2)'], label='z acceleration')
    p3.plot(jog['aT (m/s^2)'], label='total acceleration')

    p4.plot(run['ax (m/s^2)'], label='x acceleration')
    p4.plot(run['ay (m/s^2)'], label='y acceleration')
    p4.plot(run['az (m/s^2)'], label='z acceleration')
    p4.plot(run['aT (m/s^2)'], label='total acceleration')

    p1.legend()
    p2.legend()
    p3.legend()
    p4.legend()

    p1.title.set_text(user_info + ' Standing')
    p2.title.set_text(user_info + ' Walking')
    p3.title.set_text(user_info + ' Jogging')
    p4.title.set_text(user_info + ' Running')

    
    plt.show()

# %% [markdown]
# 02.1 Visualise Raw Data

# %%
# Male Leg Sensor
visualise_user_data(male1_leg_stand, male1_leg_walk, male1_leg_jog, male1_leg_run, 'Male 01 - Leg Sensor:')
##visualise_user_data(male2_leg_stand, male2_leg_walk, male2_leg_jog, male2_leg_run, 'Male 02 - Leg Sensor:')
##visualise_user_data(male3_leg_stand, male3_leg_walk, male3_leg_jog, male3_leg_run, 'Male 03 - Leg Sensor:')

# Female Leg Sensor
#visualise_user_data(female1_leg_stand, female1_leg_walk, female1_leg_jog, female1_leg_run, 'Female 01 - Leg Sensor:')
#visualise_user_data(female2_leg_stand, female2_leg_walk, female2_leg_jog, female2_leg_run, 'Female 02 - Leg Sensor:')
##visualise_user_data(female3_leg_stand, female3_leg_walk, female3_leg_jog, female3_leg_run, 'Female 03 - Leg Sensor:')

# %%
# Male 01 - Arm Sensor
visualise_user_data(male1_arm_stand, male1_arm_walk, male1_arm_jog, male1_arm_run, 'Male 01 - Arm Sensor:')
#visualise_user_data(male2_arm_stand, male2_arm_walk, male2_arm_jog, male2_arm_run, 'Male 02 - Arm Sensor:')
##visualise_user_data(male3_arm_stand, male3_arm_walk, male3_arm_jog, male3_arm_run, 'Male 03 - Arm Sensor:')

# Female 01 - Arm Sensor
#visualise_user_data(female1_arm_stand, female1_arm_walk, female1_arm_jog, female1_arm_run, 'Female 01 - Arm Sensor:')
#visualise_user_data(female1_arm_stand, female1_arm_walk, female1_arm_jog, female1_arm_run, 'Female 01 - Arm Sensor:')
#visualise_user_data(female1_arm_stand, female1_arm_walk, female1_arm_jog, female1_arm_run, 'Female 01 - Arm Sensor:')

# %%
#TODO: Distribution Viz

# %% [markdown]
# 03. Data Clean-up: standardising samples

# %% [markdown]
# 03.1 Fix sample window to 3000 observations between 1000 - 4000

# %%
def standardize_data(df):
    last = len(df) 
    df = df.drop(df.index[4001:last])
    df = df.drop(df.index[0:1000])
    return df

# %%
#Leg Filter
#Male 1
male1_leg_stand = standardize_data(male1_leg_stand)
male1_leg_walk = standardize_data(male1_leg_walk)
male1_leg_jog = standardize_data(male1_leg_jog)
male1_leg_run = standardize_data(male1_leg_run)

#Male 2
male2_leg_stand = standardize_data(male2_leg_stand)
male2_leg_walk = standardize_data(male2_leg_walk)
male2_leg_jog = standardize_data(male2_leg_jog)
male2_leg_run = standardize_data(male2_leg_run)

#Male 3
male3_leg_stand = standardize_data(male3_leg_stand)
male3_leg_walk = standardize_data(male3_leg_walk)
male3_leg_jog = standardize_data(male3_leg_jog)
male3_leg_run = standardize_data(male3_leg_run)

#Female 1
female1_leg_stand = standardize_data(female1_leg_stand)
female1_leg_walk = standardize_data(female1_leg_walk)
female1_leg_jog = standardize_data(female1_leg_jog)
female1_leg_run = standardize_data(female1_leg_run)

#Female 2
female2_leg_stand = standardize_data(female2_leg_stand)
female2_leg_walk = standardize_data(female2_leg_walk)
female2_leg_jog = standardize_data(female2_leg_jog)
female2_leg_run = standardize_data(female2_leg_run)

#Female 3
female3_leg_stand = standardize_data(female3_leg_stand)
female3_leg_walk = standardize_data(female3_leg_walk)
female3_leg_jog = standardize_data(female3_leg_jog)
female3_leg_run = standardize_data(female3_leg_run)

# %%
#ARM_SENSOR
#Male 1
male1_arm_stand = standardize_data(male1_arm_stand)
male1_arm_walk = standardize_data(male1_arm_walk)
male1_arm_jog = standardize_data(male1_arm_jog.copy())
male1_arm_run = standardize_data(male1_arm_run)

#Male 2
male2_arm_stand = standardize_data(male2_arm_stand)
male2_arm_walk = standardize_data(male2_arm_walk)
male2_arm_jog = standardize_data(male2_arm_jog)
male2_arm_run = standardize_data(male2_arm_run)

#Male 3
bw_male3_arm_stand = standardize_data(male3_arm_stand)
male3_arm_walk = standardize_data(male3_arm_walk)
male3_arm_jog = standardize_data(male3_arm_jog)
male3_arm_run = standardize_data(male3_arm_run)
#Female 1
female1_arm_stand = standardize_data(female1_arm_stand)
female1_arm_walk = standardize_data(female1_arm_walk)
female1_arm_jog = standardize_data(female1_arm_jog)
female1_arm_run = standardize_data(female1_arm_run)

#Female 2
female2_arm_stand = standardize_data(female2_arm_stand)
female2_arm_walk = standardize_data(female2_arm_walk)
female2_arm_jog = standardize_data(female2_arm_jog)
female2_arm_run = standardize_data(female2_arm_run)

#Female 3
female3_arm_stand = standardize_data(female3_arm_stand)
female3_arm_walk = standardize_data(female3_arm_walk)
female3_arm_jog = standardize_data(female3_arm_jog)
female3_arm_run = standardize_data(female3_arm_run)

# %%
#Visualise -> post standardizing
#Leg
visualise_user_data(male1_leg_stand, male1_leg_walk, male1_leg_jog, male1_leg_run, 'Male 01 - Leg Sensor:')
#Arm
visualise_user_data(male1_arm_stand, male1_arm_walk, male1_arm_jog, male1_arm_run, 'Male 01 - Arm Sensor:')

# %% [markdown]
# 03.2 Apply Butterworth Filtering

# %%
def bw_filter(data):
    order = 3
    nyq = 0.5 * 160
    high = 5 / nyq
    b, a = signal.butter(order, high, btype='lowpass')
    low_passed = signal.filtfilt(b, a, data)
    return low_passed

# %%
def bw_filter_df(df):
    df['ax (m/s^2)'] = bw_filter(df['ax (m/s^2)'])
    df['ay (m/s^2)'] = bw_filter(df['ay (m/s^2)'])
    df['az (m/s^2)'] = bw_filter(df['az (m/s^2)'])
    df['aT (m/s^2)'] = bw_filter(df['aT (m/s^2)'])
    return df

# %%
#FILTER -> LEG_SENSOR
#Male 1
bw_male1_leg_stand = bw_filter_df(male1_leg_stand)
bw_male1_leg_walk = bw_filter_df(male1_leg_walk)
bw_male1_leg_jog = bw_filter_df(male1_leg_jog.copy())
bw_male1_leg_run = bw_filter_df(male1_leg_run)

#Male 2
bw_male2_leg_stand = bw_filter_df(male2_leg_stand)
bw_male2_leg_walk = bw_filter_df(male2_leg_walk)
bw_male2_leg_jog = bw_filter_df(male2_leg_jog)
bw_male2_leg_run = bw_filter_df(male2_leg_run)

#Male 3
bw_male3_leg_stand = bw_filter_df(male3_leg_stand)
bw_male3_leg_walk = bw_filter_df(male3_leg_walk)
bw_male3_leg_jog = bw_filter_df(male3_leg_jog)
bw_male3_leg_run = bw_filter_df(male3_leg_run)

#Female 1
bw_female1_leg_stand = bw_filter_df(female1_leg_stand)
bw_female1_leg_walk = bw_filter_df(female1_leg_walk)
bw_female1_leg_jog = bw_filter_df(female1_leg_jog)
bw_female1_leg_run = bw_filter_df(female1_leg_run)

#Female 2
bw_female2_leg_stand = bw_filter_df(female2_leg_stand)
bw_female2_leg_walk = bw_filter_df(female2_leg_walk)
bw_female2_leg_jog = bw_filter_df(female2_leg_jog)
bw_female2_leg_run = bw_filter_df(female2_leg_run)

#Female 3
bw_female3_leg_stand = bw_filter_df(female3_leg_stand)
bw_female3_leg_walk = bw_filter_df(female3_leg_walk)
bw_female3_leg_jog = bw_filter_df(female3_leg_jog)
bw_female3_leg_run = bw_filter_df(female3_leg_run)

# %%
#Visualistion -> ButterWorth Effect
def bw_viz():
    plt.figure(figsize=(15,10))
    p1 = plt.subplot(2,1,1)
    #p2 = plt.subplot(4,1,2)
    p1.plot(male1_leg_jog['aT (m/s^2)'], label='Raw Signal')
    p1.plot(bw_male1_leg_jog['aT (m/s^2)'], linewidth=3, label='BW-Filter Output')
    p1.legend()
    p1.title.set_text('Male 1: Jogging (aT signal) - Noisy Sample')
    plt.show()

bw_viz()

# %%
#ARM_SENSOR
#Male 1
bw_male1_arm_stand = bw_filter_df(male1_arm_stand)
bw_male1_arm_walk = bw_filter_df(male1_arm_walk)
bw_male1_arm_jog = bw_filter_df(male1_arm_jog.copy())
bw_male1_arm_run = bw_filter_df(male1_arm_run)

#Male 2
bw_male2_arm_stand = bw_filter_df(male2_arm_stand)
bw_male2_arm_walk = bw_filter_df(male2_arm_walk)
bw_male2_arm_jog = bw_filter_df(male2_arm_jog)
bw_male2_arm_run = bw_filter_df(male2_arm_run)

#Male 3
bw_male3_arm_stand = bw_filter_df(male3_arm_stand)
bw_male3_arm_walk = bw_filter_df(male3_arm_walk)
bw_male3_arm_jog = bw_filter_df(male3_arm_jog)
bw_male3_arm_run = bw_filter_df(male3_arm_run)
#Female 1
bw_female1_arm_stand = bw_filter_df(female1_arm_stand)
bw_female1_arm_walk = bw_filter_df(female1_arm_walk)
bw_female1_arm_jog = bw_filter_df(female1_arm_jog)
bw_female1_arm_run = bw_filter_df(female1_arm_run)

#Female 2
bw_female2_arm_stand = bw_filter_df(female2_arm_stand)
bw_female2_arm_walk = bw_filter_df(female2_arm_walk)
bw_female2_arm_jog = bw_filter_df(female2_arm_jog)
bw_female2_arm_run = bw_filter_df(female2_arm_run)

#Female 3
bw_female3_arm_stand = bw_filter_df(female3_arm_stand)
bw_female3_arm_walk = bw_filter_df(female3_arm_walk)
bw_female3_arm_jog = bw_filter_df(female3_arm_jog)
bw_female3_arm_run = bw_filter_df(female3_arm_run)

# %%
#Visualise -> post bw filtering
#Leg
visualise_user_data(male1_leg_stand, male1_leg_walk, bw_male1_leg_jog, male1_leg_run, 'Male 01 - Leg Sensor:')
#Arm
visualise_user_data(male1_arm_stand, male1_arm_walk, male1_arm_jog, male1_arm_run, 'Male 01 - Arm Sensor:')

# %% [markdown]
# 04. Data Prep

# %% [markdown]
# 04.1 Data with all sample information + added infromation

# %%
#Adds other known labels to individual samples
def add_features(df, id, sex, sensor_pos, activity):
    df['id'] = id
    df['sex'] = sex
    df['sensor_pos'] = sensor_pos
    df['activity'] = activity

    return df

# %% [markdown]
# Raw Data Info (Potential) -
#     Train Cohort ID Info:
#         Female1: 1
#         Female2: 2
#         Male2: 3
#         Male3: 4
#     Test Cohort ID Info:
#         Male1: 5
#         Female3: 6

# %% [markdown]
# 04.1.1 Apply add_features on samples

# %%
#Leg Filter
#Male 1
md_male1_leg_stand = add_features(bw_male1_leg_stand.copy(), 5, 'M', 'leg', 'stand')
md_male1_leg_walk = add_features(bw_male1_leg_walk.copy(), 5, 'M', 'leg', 'walk')
md_male1_leg_jog = add_features(bw_male1_leg_jog.copy(), 5, 'M', 'leg', 'jog')
md_male1_leg_run = add_features(bw_male1_leg_run.copy(), 5, 'M', 'leg', 'run')

#Male 2
md_male2_leg_stand = add_features(bw_male2_leg_stand.copy(), 3, 'M', 'leg', 'stand')
md_male2_leg_walk = add_features(bw_male2_leg_walk.copy(), 3, 'M', 'leg', 'walk')
md_male2_leg_jog = add_features(bw_male2_leg_jog.copy(), 3, 'M', 'leg', 'jog')
md_male2_leg_run = add_features(bw_male2_leg_run.copy(), 3, 'M', 'leg', 'run')

#Male 3
md_male3_leg_stand = add_features(bw_male3_leg_stand.copy(), 4, 'M', 'leg', 'stand')
md_male3_leg_walk = add_features(bw_male3_leg_walk.copy(), 4, 'M', 'leg', 'walk')
md_male3_leg_jog = add_features(bw_male3_leg_jog.copy(), 4, 'M', 'leg', 'jog')
md_male3_leg_run = add_features(bw_male3_leg_run.copy(), 4, 'M', 'leg', 'run')

#Female 1
md_female1_leg_stand = add_features(bw_female1_leg_stand.copy(), 1, 'F', 'leg', 'stand')
md_female1_leg_walk = add_features(bw_female1_leg_walk.copy(), 1, 'F', 'leg', 'walk')
md_female1_leg_jog = add_features(bw_female1_leg_jog.copy(), 1, 'F', 'leg', 'jog')
md_female1_leg_run = add_features(bw_female1_leg_run.copy(), 1, 'F', 'leg', 'run')

#Female 2
md_female2_leg_stand = add_features(bw_female2_leg_stand.copy(), 2, 'F', 'leg', 'stand')
md_female2_leg_walk = add_features(bw_female2_leg_walk.copy(), 2, 'F', 'leg', 'walk')
md_female2_leg_jog = add_features(bw_female2_leg_jog.copy(), 2, 'F', 'leg', 'jog')
md_female2_leg_run = add_features(bw_female2_leg_run.copy(), 2, 'F', 'leg', 'run')

#Female 3
md_female3_leg_stand = add_features(bw_female3_leg_stand.copy(), 6, 'F', 'leg', 'stand')
md_female3_leg_walk = add_features(bw_female3_leg_walk.copy(), 6, 'F', 'leg', 'walk')
md_female3_leg_jog = add_features(bw_female3_leg_jog.copy(), 6, 'F', 'leg', 'jog')
md_female3_leg_run = add_features(bw_female3_leg_run.copy(), 6, 'F', 'leg', 'run')

# %%
#ARM_SENSOR
#Male 1
md_male1_arm_stand = add_features(bw_male1_arm_stand.copy(), 5, 'M', 'arm', 'stand')
md_male1_arm_walk = add_features(bw_male1_arm_walk.copy(), 5, 'M', 'arm', 'walk')
md_male1_arm_jog = add_features(bw_male1_arm_jog.copy(), 5, 'M', 'arm', 'jog')
md_male1_arm_run = add_features(bw_male1_arm_run.copy(), 5, 'M', 'arm', 'run')

#Male 2
md_male2_arm_stand = add_features(bw_male2_arm_stand.copy(), 3, 'M', 'arm', 'stand')
md_male2_arm_walk = add_features(bw_male2_arm_walk.copy(), 3, 'M', 'arm', 'walk')
md_male2_arm_jog = add_features(bw_male2_arm_jog.copy(), 3, 'M', 'arm', 'jog')
md_male2_arm_run = add_features(bw_male2_arm_run.copy(), 3, 'M', 'arm', 'run')

#Male 3
md_male3_arm_stand = add_features(bw_male3_arm_stand.copy(), 4, 'M', 'arm', 'stand')
md_male3_arm_walk = add_features(bw_male3_arm_walk.copy(), 4, 'M', 'arm', 'walk')
md_male3_arm_jog = add_features(bw_male3_arm_jog.copy(), 4, 'M', 'arm', 'jog')
md_male3_arm_run = add_features(bw_male3_arm_run.copy(), 4, 'M', 'arm', 'run')
#Female 1
md_female1_arm_stand = add_features(bw_female1_arm_stand.copy(), 1, 'F', 'arm', 'stand')
md_female1_arm_walk = add_features(bw_female1_arm_walk.copy(), 1, 'F', 'arm', 'walk')
md_female1_arm_jog = add_features(bw_female1_arm_jog.copy(), 1, 'F', 'arm', 'jog')
md_female1_arm_run = add_features(bw_female1_arm_run.copy(), 1, 'F', 'arm', 'run')

#Female 2
md_female2_arm_stand = add_features(bw_female2_arm_stand.copy(), 2, 'F', 'arm', 'stand')
md_female2_arm_walk = add_features(bw_female2_arm_walk.copy(), 2, 'F', 'arm', 'walk')
md_female2_arm_jog = add_features(bw_female2_arm_jog.copy(), 2, 'F', 'arm', 'jog')
md_female2_arm_run = add_features(bw_female2_arm_run.copy(), 2, 'F', 'arm', 'run')

#Female 3
md_female3_arm_stand = add_features(bw_female3_arm_stand.copy(), 6, 'F', 'arm', 'stand')
md_female3_arm_walk = add_features(bw_female3_arm_walk.copy(), 6, 'F', 'arm', 'walk')
md_female3_arm_jog = add_features(bw_female3_arm_jog.copy(), 6, 'F', 'arm', 'jog')
md_female3_arm_run = add_features(bw_female3_arm_run.copy(), 6, 'F', 'arm', 'run')

# %% [markdown]
# 04.1.2 Concat samples for cohesive leg and arm sensor data

# %%
leg_master_data = pd.concat([md_male1_leg_stand,
                            md_male1_leg_walk,
                            md_male1_leg_jog,
                            md_male1_leg_run,
                            md_male2_leg_stand,
                            md_male2_leg_walk,
                            md_male2_leg_jog,
                            md_male2_leg_run,
                            md_male3_leg_stand,
                            md_male3_leg_walk,
                            md_male3_leg_jog,
                            md_male3_leg_run,
                            md_female1_leg_stand,
                            md_female1_leg_walk,
                            md_female1_leg_jog,
                            md_female1_leg_run,
                            md_female2_leg_stand,
                            md_female2_leg_walk,
                            md_female2_leg_jog,
                            md_female2_leg_run,
                            md_female3_leg_stand,
                            md_female3_leg_walk,
                            md_female3_leg_jog,
                            md_female3_leg_run])

# %%
arm_master_data = pd.concat([md_male1_arm_stand,
                            md_male1_arm_walk,
                            md_male1_arm_jog,
                            md_male1_arm_run,
                            md_male2_arm_stand,
                            md_male2_arm_walk,
                            md_male2_arm_jog,
                            md_male2_arm_run,
                            md_male3_arm_stand,
                            md_male3_arm_walk,
                            md_male3_arm_jog,
                            md_male3_arm_run,
                            md_female1_arm_stand,
                            md_female1_arm_walk,
                            md_female1_arm_jog,
                            md_female1_arm_run,
                            md_female2_arm_stand,
                            md_female2_arm_walk,
                            md_female2_arm_jog,
                            md_female2_arm_run,
                            md_female3_arm_stand,
                            md_female3_arm_walk,
                            md_female3_arm_jog,
                            md_female3_arm_run])

# %% [markdown]
# 04.1.3 Reshape Index column

# %%
leg_master_data.reset_index()
# Out:
#        index       time  ax (m/s^2)  ay (m/s^2)  az (m/s^2)  aT (m/s^2)  id  \
# 0       1000   4.739343    0.030621   -0.022203   -0.009682    0.034189   5
# 1       1001   4.744382    0.027262   -0.020001   -0.009283    0.032128   5
# 2       1002   4.748828    0.023840   -0.017841   -0.008865    0.030164   5
# 3       1003   4.753734    0.020396   -0.015750   -0.008435    0.028342   5
# 4       1004   4.758657    0.016968   -0.013752   -0.007997    0.026703   5
# ...      ...        ...         ...         ...         ...         ...  ..
# 72019   3996  18.946223   22.791914   27.373685  -14.857498   43.257409   6
# 72020   3997  18.949989   20.528151   28.596417  -15.046075   42.933819   6
# 72021   3998  18.956912   18.230342   29.924920  -15.172437   42.632990   6
# 72022   3999  18.960789   15.970673   31.306101  -15.246850   42.363829   6
# 72023   4000  18.965958   13.815200   32.685742  -15.279667   42.130886   6
#
#       sex sensor_pos activity
# ...

# %%
arm_master_data.reset_index()
# Out:
#        index       time  ax (m/s^2)  ay (m/s^2)  az (m/s^2)  aT (m/s^2)  id  \
# 0       1000   4.734730   -0.032592   -0.006583    0.007256    0.033935   5
# 1       1001   4.739850   -0.024281   -0.005289    0.003177    0.035756   5
# 2       1002   4.742579   -0.016148   -0.004111   -0.000655    0.037424   5
# 3       1003   4.747128   -0.008339   -0.003038   -0.004162    0.038904   5
# 4       1004   4.751832   -0.000987   -0.002065   -0.007272    0.040162   5
# ...      ...        ...         ...         ...         ...         ...  ..
# 73408   3996  18.944560    1.116988   15.112146    0.646623   15.018297   6
# 73409   3997  18.949761    1.186403   14.722405    1.099512   14.597961   6
# 73410   3998  18.954990    1.231694   14.287361    1.507172   14.146947   6
# 73411   3999  18.958912    1.259085   13.829601    1.865637   13.682890   6
# 73412   4000  18.964624    1.273862   13.369961    2.173855   13.222938   6
#
#       sex sensor_pos activity
# ...

# %% [markdown]
# 04.1.4 Save dfs into csvs

# %%
leg_master_data.to_csv('processed_data/uncompressed_legsensor_data.csv')
arm_master_data.to_csv('processed_data/uncompressed_armsensor_data.csv')

# %%
master_data = pd.concat([leg_master_data,arm_master_data])
master_data.reset_index()
# Out:
#         index       time  ax (m/s^2)  ay (m/s^2)  az (m/s^2)  aT (m/s^2)  id  \
# 0        1000   4.739343    0.030621   -0.022203   -0.009682    0.034189   5
# 1        1001   4.744382    0.027262   -0.020001   -0.009283    0.032128   5
# 2        1002   4.748828    0.023840   -0.017841   -0.008865    0.030164   5
# 3        1003   4.753734    0.020396   -0.015750   -0.008435    0.028342   5
# 4        1004   4.758657    0.016968   -0.013752   -0.007997    0.026703   5
# ...       ...        ...         ...         ...         ...         ...  ..
# 145432   3996  18.944560    1.116988   15.112146    0.646623   15.018297   6
# 145433   3997  18.949761    1.186403   14.722405    1.099512   14.597961   6
# 145434   3998  18.954990    1.231694   14.287361    1.507172   14.146947   6
# 145435   3999  18.958912    1.259085   13.829601    1.865637   13.682890   6
# 145436   4000  18.964624    1.273862   13.369961    2.173855   13.222938   6
#
#        sex sensor_pos activity
# ...

# %%
master_data.to_csv('processed_data/uncompressed_data.csv')

# %% [markdown]
# 04.2 Feature engineering on sample data

# %%
#Lists to catch windows
ax_list = []
ay_list = []
az_list = []
aT_list = []
id_list = []
activity_list = []
sex_list = []
sensor_pos_list = []

# %%
#Prep Data
def standardize_features(df, id, sex, sensor_pos, activity):
    window = 50
    step = 25

    for i in range(0, df.shape[0] - window, step):
        ax_step = df['ax (m/s^2)'].values[i: i + 100]
        ay_step = df['ay (m/s^2)'].values[i: i + 100]
        az_step = df['az (m/s^2)'].values[i: i + 100]
        aT_step = df['aT (m/s^2)'].values[i: i + 100]

        ax_list.append(ax_step)
        ay_list.append(ay_step)
        az_list.append(az_step)
        aT_list.append(aT_step)
        id_list.append(id)
        sex_list.append(sex)
        sensor_pos_list.append(sensor_pos)
        activity_list.append(activity)

# %%
#Apply Features
def fe_ml_dataset_prep():
    df = pd.DataFrame()

    #mean
    df['ax_mean'] = pd.Series(ax_list).apply(lambda x: x.mean())
    df['ay_mean'] = pd.Series(ay_list).apply(lambda x: x.mean())
    df['az_mean'] = pd.Series(az_list).apply(lambda x: x.mean())
    df['aT_mean'] = pd.Series(aT_list).apply(lambda x: x.mean())

    #absolute difference - mean
    df['ax_ad_mean'] = pd.Series(ax_list).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
    df['ay_ad_mean'] = pd.Series(ay_list).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
    df['az_ad_mean'] = pd.Series(az_list).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))
    df['aT_ad_mean'] = pd.Series(aT_list).apply(lambda x: np.mean(np.absolute(x - np.mean(x))))

    #min
    df['ax_min'] = pd.Series(ax_list).apply(lambda x: x.min())
    df['ay_min'] = pd.Series(ay_list).apply(lambda x: x.min())
    df['az_min'] = pd.Series(az_list).apply(lambda x: x.min())
    df['aT_min'] = pd.Series(aT_list).apply(lambda x: x.min())

    #max
    df['ax_max'] = pd.Series(ax_list).apply(lambda x: x.max())
    df['ay_max'] = pd.Series(ay_list).apply(lambda x: x.max())
    df['az_max'] = pd.Series(az_list).apply(lambda x: x.max())
    df['aT_max'] = pd.Series(aT_list).apply(lambda x: x.max())

    #standard deviation
    df['ax_std'] = pd.Series(ax_list).apply(lambda x: x.std())
    df['ay_std'] = pd.Series(ay_list).apply(lambda x: x.std())
    df['az_std'] = pd.Series(az_list).apply(lambda x: x.std())
    df['aT_std'] = pd.Series(aT_list).apply(lambda x: x.std())

    #median
    df['ax_median'] = pd.Series(ax_list).apply(lambda x: np.median(x))
    df['ay_median'] = pd.Series(ay_list).apply(lambda x: np.median(x))
    df['az_median'] = pd.Series(az_list).apply(lambda x: np.median(x))
    df['aT_median'] = pd.Series(aT_list).apply(lambda x: np.median(x))

    #absolute difference - median
    df['ax_ad_median'] = pd.Series(ax_list).apply(lambda x: np.median(np.absolute(x - np.median(x))))
    df['ay_ad_median'] = pd.Series(ay_list).apply(lambda x: np.median(np.absolute(x - np.median(x))))
    df['az_ad_median'] = pd.Series(az_list).apply(lambda x: np.median(np.absolute(x - np.median(x))))
    df['aT_ad_median'] = pd.Series(aT_list).apply(lambda x: np.median(np.absolute(x - np.median(x))))

    #max - min
    df['ax_mm_diff'] = df['ax_max'] - df['ax_min']
    df['ay_mm_diff'] = df['ay_max'] - df['ay_min']
    df['az_mm_diff'] = df['az_max'] - df['az_min']
    df['aT_mm_diff'] = df['aT_max'] - df['aT_min']

    #interquatile range
    df['ax_iqr'] = pd.Series(ax_list).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
    df['ay_iqr'] = pd.Series(ay_list).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
    df['az_iqr'] = pd.Series(az_list).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))
    df['aT_iqr'] = pd.Series(aT_list).apply(lambda x: np.percentile(x, 75) - np.percentile(x, 25))

    #pos count
    df['ax_pos_count'] = pd.Series(ax_list).apply(lambda x: np.sum(x > 0))
    df['ay_pos_count'] = pd.Series(ay_list).apply(lambda x: np.sum(x > 0))
    df['az_pos_count'] = pd.Series(az_list).apply(lambda x: np.sum(x > 0))
    df['aT_pos_count'] = pd.Series(aT_list).apply(lambda x: np.sum(x > 0))

    #neg count
    df['ax_neg_count'] = pd.Series(ax_list).apply(lambda x: np.sum(x < 0))
    df['ay_neg_count'] = pd.Series(ay_list).apply(lambda x: np.sum(x < 0))
    df['az_neg_count'] = pd.Series(az_list).apply(lambda x: np.sum(x < 0))
    df['aT_neg_count'] = pd.Series(aT_list).apply(lambda x: np.sum(x < 0))

    #peaks
    df['ax_peaks'] = pd.Series(ax_list).apply(lambda x: np.sum(x > x.mean()))
    df['ay_peaks'] = pd.Series(ay_list).apply(lambda x: np.sum(x > x.mean()))
    df['az_peaks'] = pd.Series(az_list).apply(lambda x: np.sum(x > x.mean()))
    df['aT_peaks'] = pd.Series(aT_list).apply(lambda x: np.sum(x > x.mean()))

    #kurtosis
    df['ax_kurtosis'] = pd.Series(ax_list).apply(lambda x: stats.kurtosis(x))
    df['ay_kurtosis'] = pd.Series(ay_list).apply(lambda x: stats.kurtosis(x))
    df['az_kurtosis'] = pd.Series(az_list).apply(lambda x: stats.kurtosis(x))
    df['aT_kurtosis'] = pd.Series(aT_list).apply(lambda x: stats.kurtosis(x))

    #skewness
    df['ax_skewness'] = pd.Series(ax_list).apply(lambda x: stats.skew(x))
    df['ay_skewness'] = pd.Series(ay_list).apply(lambda x: stats.skew(x))
    df['az_skewness'] = pd.Series(az_list).apply(lambda x: stats.skew(x))
    df['aT_skewness'] = pd.Series(aT_list).apply(lambda x: stats.skew(x))

    #energy
    df['ax_energy'] = pd.Series(ax_list).apply(lambda x: np.sum(x**2)/50)
    df['ay_energy'] = pd.Series(ay_list).apply(lambda x: np.sum(x**2)/50)
    df['az_energy'] = pd.Series(az_list).apply(lambda x: np.sum(x**2)/50)
    df['aT_energy'] = pd.Series(aT_list).apply(lambda x: np.sum(x**2)/50)

    #labels
    df['id'] = id_list
    df['sex'] = sex_list
    df['sensor_pos'] = sensor_pos_list
    df['activity'] = activity_list

    return df

# %%
#Leg Filter
#Male 1
standardize_features(bw_male1_leg_stand.copy(), 5, 'M', 'leg', 'stand')
standardize_features(bw_male1_leg_walk.copy(), 5, 'M', 'leg', 'walk')
standardize_features(bw_male1_leg_jog.copy(), 5, 'M', 'leg', 'jog')
standardize_features(bw_male1_leg_run.copy(), 5, 'M', 'leg', 'run')

#Male 2
standardize_features(bw_male2_leg_stand.copy(), 3, 'M', 'leg', 'stand')
standardize_features(bw_male2_leg_walk.copy(), 3, 'M', 'leg', 'walk')
standardize_features(bw_male2_leg_jog.copy(), 3, 'M', 'leg', 'jog')
standardize_features(bw_male2_leg_run.copy(), 3, 'M', 'leg', 'run')

#Male 3
standardize_features(bw_male3_leg_stand.copy(), 4, 'M', 'leg', 'stand')
standardize_features(bw_male3_leg_walk.copy(), 4, 'M', 'leg', 'walk')
standardize_features(bw_male3_leg_jog.copy(), 4, 'M', 'leg', 'jog')
standardize_features(bw_male3_leg_run.copy(), 4, 'M', 'leg', 'run')

#Female 1
standardize_features(bw_female1_leg_stand.copy(), 1, 'F', 'leg', 'stand')
standardize_features(bw_female1_leg_walk.copy(), 1, 'F', 'leg', 'walk')
standardize_features(bw_female1_leg_jog.copy(), 1, 'F', 'leg', 'jog')
standardize_features(bw_female1_leg_run.copy(), 1, 'F', 'leg', 'run')

#Female 2
standardize_features(bw_female2_leg_stand.copy(), 2, 'F', 'leg', 'stand')
standardize_features(bw_female2_leg_walk.copy(), 2, 'F', 'leg', 'walk')
standardize_features(bw_female2_leg_jog.copy(), 2, 'F', 'leg', 'jog')
standardize_features(bw_female2_leg_run.copy(), 2, 'F', 'leg', 'run')

#Female 3
standardize_features(bw_female3_leg_stand.copy(), 6, 'F', 'leg', 'stand')
standardize_features(bw_female3_leg_walk.copy(), 6, 'F', 'leg', 'walk')
standardize_features(bw_female3_leg_jog.copy(), 6, 'F', 'leg', 'jog')
standardize_features(bw_female3_leg_run.copy(), 6, 'F', 'leg', 'run')

# %%
fe_ml_leg = fe_ml_dataset_prep()

# %%
fe_ml_leg
# Out:
#         ax_mean    ay_mean   az_mean    aT_mean  ax_ad_mean  ay_ad_mean  \
# 0      0.008389   0.002299 -0.005565   0.052762    0.018978    0.007285
# 1      0.004237   0.004799 -0.003213   0.056464    0.022196    0.006363
# 2      0.004794   0.004276 -0.006235   0.055496    0.018700    0.006834
# 3      0.002024   0.003511 -0.001768   0.048095    0.017400    0.005763
# 4      0.005332   0.002019 -0.001356   0.050343    0.021216    0.003858
# ...         ...        ...       ...        ...         ...         ...
# 2851  -0.963213   5.205235 -4.198882  33.891881   18.145530   14.477348
# 2852 -10.152798  -0.418454 -1.864496  33.999321   12.481099   10.166552
# 2853  -5.433769   4.593402 -3.230471  39.367586   16.745569   14.312291
# 2854  -6.229861  11.100801 -4.330511  45.403258   18.926813   13.526015
# 2855   5.852139  16.397709 -5.724484  42.100074   15.919056   13.312740
#
#       az_ad_mean  aT_ad_mean     ax_min     ay_min  ...  az_skewness  \
# ...

# %%
#Reset List
del ax_list[:]
del ay_list[:]
del az_list[:]
del aT_list[:]
del id_list[:]
del activity_list[:]
del sex_list[:]
del sensor_pos_list[:]

# %%
#Arm Filter
#Male 1
standardize_features(bw_male1_arm_stand.copy(), 5, 'M', 'arm', 'stand')
standardize_features(bw_male1_arm_walk.copy(), 5, 'M', 'arm', 'walk')
standardize_features(bw_male1_arm_jog.copy(), 5, 'M', 'arm', 'jog')
standardize_features(bw_male1_arm_run.copy(), 5, 'M', 'arm', 'run')

#Male 2
standardize_features(bw_male2_arm_stand.copy(), 3, 'M', 'arm', 'stand')
standardize_features(bw_male2_arm_walk.copy(), 3, 'M', 'arm', 'walk')
standardize_features(bw_male2_arm_jog.copy(), 3, 'M', 'arm', 'jog')
standardize_features(bw_male2_arm_run.copy(), 3, 'M', 'arm', 'run')

#Male 3
standardize_features(bw_male3_arm_stand.copy(), 4, 'M', 'arm', 'stand')
standardize_features(bw_male3_arm_walk.copy(), 4, 'M', 'arm', 'walk')
standardize_features(bw_male3_arm_jog.copy(), 4, 'M', 'arm', 'jog')
standardize_features(bw_male3_arm_run.copy(), 4, 'M', 'arm', 'run')

#Female 1
standardize_features(bw_female1_arm_stand.copy(), 1, 'F', 'arm', 'stand')
standardize_features(bw_female1_arm_walk.copy(), 1, 'F', 'arm', 'walk')
standardize_features(bw_female1_arm_jog.copy(), 1, 'F', 'arm', 'jog')
standardize_features(bw_female1_arm_run.copy(), 1, 'F', 'arm', 'run')

#Female 2
standardize_features(bw_female2_arm_stand.copy(), 2, 'F', 'arm', 'stand')
standardize_features(bw_female2_arm_walk.copy(), 2, 'F', 'arm', 'walk')
standardize_features(bw_female2_arm_jog.copy(), 2, 'F', 'arm', 'jog')
standardize_features(bw_female2_arm_run.copy(), 2, 'F', 'arm', 'run')

#Female 3
standardize_features(bw_female3_arm_stand.copy(), 6, 'F', 'arm', 'stand')
standardize_features(bw_female3_arm_walk.copy(), 6, 'F', 'arm', 'walk')
standardize_features(bw_female3_arm_jog.copy(), 6, 'F', 'arm', 'jog')
standardize_features(bw_female3_arm_run.copy(), 6, 'F', 'arm', 'run')

# %%
fe_ml_arm = fe_ml_dataset_prep()
fe_ml_arm
# Out:
#         ax_mean   ay_mean   az_mean    aT_mean  ax_ad_mean  ay_ad_mean  \
# 0      0.010215 -0.004154 -0.000269   0.055814    0.016998    0.016951
# 1      0.004390 -0.003902  0.006497   0.071573    0.012472    0.020720
# 2      0.004428  0.004871  0.001023   0.083406    0.012304    0.030754
# 3     -0.000963  0.007763 -0.001264   0.083405    0.016003    0.028498
# 4     -0.004210  0.007837 -0.010616   0.082233    0.015649    0.030292
# ...         ...       ...       ...        ...         ...         ...
# 2906   5.304296  6.992285 -7.357166  20.077278    7.788882   10.934353
# 2907   1.353025  2.949142 -5.974860  20.573900   11.762721   10.300356
# 2908  -3.024489  7.247215 -3.938283  19.358044    9.439023    9.714546
# 2909  -7.953697  9.211947 -1.493172  18.164470    7.121034    8.891033
# 2910 -10.426398  4.460931  0.603867  16.341648    7.344821    7.095706
#
#       az_ad_mean  aT_ad_mean     ax_min     ay_min  ...  az_skewness  \
# ...

# %% [markdown]
# 04.2.x Save Compressed (F.E.) data

# %%
fe_ml_leg.to_csv('processed_data/fe_legsensor_data.csv')
fe_ml_arm.to_csv('processed_data/fe_armsensor_data.csv')

# %%
fe_ml = pd.concat([fe_ml_leg, fe_ml_arm])

# %%
fe_ml.to_csv('processed_data/fe_data.csv')
